# %%
list=[1,"john",2]
print(list)
# Out:
# [1, 'john', 2]

# %%
print(list[1:])
print(list[1:3])
print(list[1:2])
print(list[:2])
# Out:
# ['john', 2]
# ['john', 2]
# ['john']
# [1, 'john']

# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv("US counties - education vs per capita personal income - results-20221227-213216.csv")

# %%
data1.head()
# Out:
#    county_FIPS state          county  per_capita_personal_income_2019  \
# 0        51013    VA   Arlington, VA                            97629
# 1        35028    NM  Los Alamos, NM                            72366
# 2         8013    CO     Boulder, CO                            79698
# 3        24027    MD      Howard, MD                            78013
# 4        36061    NY    New York, NY                           173525
#
#    per_capita_personal_income_2020  per_capita_personal_income_2021  \
# 0                           100687                           107603
# 1                            75949                            81306
# 2                            83173                            89593
# 3                            82041                            86380
# 4                           175327                           195543
#
#    associate_degree_numbers_2016_2020  bachelor_degree_numbers_2016_2020  \
# ...

# %%
len(data1)
# Out:
# 3006

# %%
data1["county_FIPS"]
# Out:
# 0       51013
# 1       35028
# 2        8013
# 3       24027
# 4       36061
#         ...
# 3001    13165
# 3002    28055
# 3003     2158
# 3004    48261
# 3005    48301
# Name: county_FIPS, Length: 3006, dtype: int64

# %%
data1[200:201]
# Out:
#      county_FIPS state              county  per_capita_personal_income_2019  \
# 200         2068    AK  Denali Borough, AK                           102888
#
#      per_capita_personal_income_2020  per_capita_personal_income_2021  \
# 200                            91233                           107916
#
#      associate_degree_numbers_2016_2020  bachelor_degree_numbers_2016_2020  \
# 200                                 531                                730
#
#      associate_degree_percentage_2016_2020  \
# 200                                  28.46
#
#      bachelor_degree_percentage_2015_2019
# 200                                 39.12

# %%
data1.head(10)
# Out:
#    county_FIPS state          county  per_capita_personal_income_2019  \
# 0        51013    VA   Arlington, VA                            97629
# 1        35028    NM  Los Alamos, NM                            72366
# 2         8013    CO     Boulder, CO                            79698
# 3        24027    MD      Howard, MD                            78013
# 4        36061    NY    New York, NY                           173525
# 5        51107    VA     Loudoun, VA                            82681
# 6         8097    CO      Pitkin, CO                           183241
# 7        37135    NC      Orange, NC                            66970
# 8        47187    TN  Williamson, TN                            95806
# 9         6041    CA       Marin, CA                           139891
#
#    per_capita_personal_income_2020  per_capita_personal_income_2021  \
# 0                           100687                           107603
# ...

# %%
data1.isnull().sum()
# Out:
# county_FIPS                              0
# state                                    0
# county                                   0
# per_capita_personal_income_2019          0
# per_capita_personal_income_2020          0
# per_capita_personal_income_2021          0
# associate_degree_numbers_2016_2020       0
# bachelor_degree_numbers_2016_2020        0
# associate_degree_percentage_2016_2020    0
# bachelor_degree_percentage_2015_2019     0
# dtype: int64

# %%
data1.drop("county_FIPS",axis=1)
# Out:
#      state                    county  per_capita_personal_income_2019  \
# 0       VA             Arlington, VA                            97629
# 1       NM            Los Alamos, NM                            72366
# 2       CO               Boulder, CO                            79698
# 3       MD                Howard, MD                            78013
# 4       NY              New York, NY                           173525
# ...    ...                       ...                              ...
# 3001    GA               Jenkins, GA                            30946
# 3002    MS             Issaquena, MS                            24805
# 3003    AK  Kusilvak Census Area, AK                            31050
# 3004    TX                Kenedy, TX                            43786
# 3005    TX                Loving, TX                           108522
#
#       per_capita_personal_income_2020  per_capita_personal_income_2021  \
# ...

# %%
data1.drop([2,5],axis=0)
# Out:
#       county_FIPS state                    county  \
# 0           51013    VA             Arlington, VA
# 1           35028    NM            Los Alamos, NM
# 3           24027    MD                Howard, MD
# 4           36061    NY              New York, NY
# 6            8097    CO                Pitkin, CO
# ...           ...   ...                       ...
# 3001        13165    GA               Jenkins, GA
# 3002        28055    MS             Issaquena, MS
# 3003         2158    AK  Kusilvak Census Area, AK
# 3004        48261    TX                Kenedy, TX
# 3005        48301    TX                Loving, TX
#
#       per_capita_personal_income_2019  per_capita_personal_income_2020  \
# 0                               97629                           100687
# 1                               72366                            75949
# 3                               78013                            82041
# 4                              173525                           175327
# ...

# %%
data1.dropna()
# Out:
#       county_FIPS state                    county  \
# 0           51013    VA             Arlington, VA
# 1           35028    NM            Los Alamos, NM
# 2            8013    CO               Boulder, CO
# 3           24027    MD                Howard, MD
# 4           36061    NY              New York, NY
# ...           ...   ...                       ...
# 3001        13165    GA               Jenkins, GA
# 3002        28055    MS             Issaquena, MS
# 3003         2158    AK  Kusilvak Census Area, AK
# 3004        48261    TX                Kenedy, TX
# 3005        48301    TX                Loving, TX
#
#       per_capita_personal_income_2019  per_capita_personal_income_2020  \
# 0                               97629                           100687
# 1                               72366                            75949
# 2                               79698                            83173
# 3                               78013                            82041
# ...

# %%
data1
# Out:
#       county_FIPS  state                    county  \
# 0           51013    NaN             Arlington, VA
# 1           35028    NaN            Los Alamos, NM
# 2            8013    NaN               Boulder, CO
# 3           24027    NaN                Howard, MD
# 4           36061    NaN              New York, NY
# ...           ...    ...                       ...
# 3001        13165    NaN               Jenkins, GA
# 3002        28055    NaN             Issaquena, MS
# 3003         2158    NaN  Kusilvak Census Area, AK
# 3004        48261    NaN                Kenedy, TX
# 3005        48301    NaN                Loving, TX
#
#       per_capita_personal_income_2019  per_capita_personal_income_2020  \
# 0                               97629                           100687
# 1                               72366                            75949
# 2                               79698                            83173
# ...
