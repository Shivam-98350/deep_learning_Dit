# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('housepriceprediction.xlsx')

# %%
print(len(df))
df.head()
# Out:
# 100
#    Area    Price
# 0  4294  4319764
# 1    98   470596
# 2  1936  7680112
# 3  1943  2539501
# 4  1462  2861134

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import linear_model

# %%
#plotting Scatter plot of the data
plt.scatter(df.Area,df.Price,c='green',marker='1')
plt.xlabel("Area")
plt.ylabel("Price")
plt.plot(df.Area,df.Price,c="pink")

# %% [markdown]
# # finding slope and intercept

# %%
x=linear_model.LinearRegression()
# fit method takes taraining data as an argument
x.fit(df[['Area']],df.Price)
# Out:
# LinearRegression()

# %%
print(x.intercept_)
print(x.coef_)
# Out:
# -406513.94311254285
# [3067.52953332]

# %%
from sklearn.preprocessing import PolynomialFeatures
